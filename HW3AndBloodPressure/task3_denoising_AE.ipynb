# %% [markdown]
# # Implementing a denoising autoencoder
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [HW page](http://kovan.ceng.metu.edu.tr/~sinan/DL/index.html) on the course website.*
#
# In this exercise we will develop a denoising autoencoder, and test it out on the MNIST dataset.

# %%
# A bit of setup

import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
  """ returns relative error """
  return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %% [markdown]
# We will use the class `DenoisingAutoencoder` in the file `METU/denoising_autoencoder.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
from METU.denoising_autoencoder import DenoisingAutoencoder
from METU.Noise import Noise, GaussianNoise

# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 2
num_inputs = 100
# Outputs are equal to the inputs
network_size = (input_size, hidden_size, input_size)

def init_toy_model(num_inputs, input_size):
  np.random.seed(0)
  net = DenoisingAutoencoder((input_size, hidden_size, input_size))
  net.init_weights()
  return net

def init_toy_data(num_inputs, input_size):
  np.random.seed(1)
  X = np.random.randn(num_inputs, input_size)
  return X

net = init_toy_model(num_inputs, input_size)
X = init_toy_data(num_inputs, input_size)
print("Ok, now we have a toy network")
# Out:
# Ok, now we have a toy network

# %% [markdown]
# # Forward pass: compute loss
# Open the file `METU/denoising_autoencoder.py` and look at the method `DenoisingAutoencoder.loss`. This function is very similar to the loss functions you have written in the first HWs: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for the corrupted input. In the same function, implement the second part that computes the data and the regularization losses.

# %%
print(X.shape)
loss,_ = net.loss(GaussianNoise(0.5)(X), X, reg=3e-3, activation_function='SIGMOID')

correct_loss = 2.42210627243
print('Your loss value:' + str(loss))

print('Difference between your loss and correct loss:')
print(np.sum(np.abs(loss - correct_loss)))
# Out:
# (100, 4)
# Your loss value:2.4155692938525335
# Difference between your loss and correct loss:
# 0.006536978577466712

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from METU.gradient_check import eval_numerical_gradient

reg = 3e-3

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

net.init_weights()
noisy_X = GaussianNoise(0.5)(X)
loss, grads = net.loss(noisy_X, X, reg, activation_function='TANH')

# these should all be less than 1e-5 or so
f = lambda W: net.loss(noisy_X, X, reg, activation_function='TANH')[0]
W1_grad = eval_numerical_gradient(f, net.weights[1]['W'], verbose=False)
print('{:s} max relative error: {:e}'.format("W1", rel_error(W1_grad, grads['W1'])))
W0_grad = eval_numerical_gradient(f, net.weights[0]['W'], verbose=False)
print('{:s} max relative error: {:e}'.format("W0", rel_error(W0_grad, grads['W0'])))
# Out:
# W1 max relative error: 9.801983e-01
# W0 max relative error: 9.897187e-01

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD). Look at the function `DenoisingAutoencoder.train_with_SGD` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedures you used in the first HW.
#
# Once you have implemented the method, run the code below to train the network on toy data. You should achieve a training loss less than 2.0.

# %%
net = init_toy_model(num_inputs, input_size)
reg = 3e-3
stats = net.train_with_SGD(X, noise=GaussianNoise(sd=0.5),
            learning_rate=0.0086, learning_rate_decay=0.94, 
            reg=reg, batchsize=100, num_iters=500, verbose=False, activation_function='sigmoid')

print('Final training loss: ', stats['loss_history'][-1])
# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  1.6633078072762413

# %% [markdown]
# # Load the data
# Now that you have implemented a DAE network that passes gradient checks and works on toy data, it's time to load up the MNIST dataset so we can use it to train DAE on a real dataset. Make sure that you have run "cs231n/datasets/get_datasets.sh" script before you continue with this step.

# %%
from cs231n.data_utils import load_mnist

X_train, y_train, X_val, y_val, X_test, y_test = load_mnist()
X_train = X_train.reshape(X_train.shape[0], -1)
X_val = X_val.reshape(X_val.shape[0], -1)
X_test = X_test.reshape(X_test.shape[0], -1)
    
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (50000, 784)
# Train labels shape:  (50000,)
# Test data shape:  (10000, 784)
# Test labels shape:  (10000,)

# %%
#Visualize some samples

x = np.reshape(X_train[100], (28,28))

plt.imshow(x)
plt.title(y_train[0])
plt.show()

plt.imshow(GaussianNoise(rate=0.5,sd=0.5)(x))
plt.show()
# Yes, DAE will learn to reconstruct from such corrupted data

# %% [markdown]
# # Train a network
# To train our network we will use SGD with momentum. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
import time

input_size = 28 * 28
hidden_size = 300 # Try also sizes bigger than 28*28

reg = 1e-5 # 3e-3

net = DenoisingAutoencoder((input_size, hidden_size, input_size))
net.init_weights(13)

# Train with SGD
tic = time.time()
stats = net.train_with_SGD(X_train, noise=GaussianNoise(rate=0.5,sd=0.5),
            learning_rate=8e-3, learning_rate_decay=0.90, 
            reg=reg, num_iters=1000, batchsize=128, momentum='classic', mu=0.9, verbose=True, 
            activation_function='sigmoid')
toc = time.time()
print(toc-tic, 'sec elapsed')
# Out:
# SGD: iteration 0 / 1000: loss 93.480481
# SGD: iteration 10 / 1000: loss 24.604525
# SGD: iteration 20 / 1000: loss 21.989974
# SGD: iteration 30 / 1000: loss 19.048340
# SGD: iteration 40 / 1000: loss 17.645891
# SGD: iteration 50 / 1000: loss 17.453565
# SGD: iteration 60 / 1000: loss 16.689859
# SGD: iteration 70 / 1000: loss 16.726988
# SGD: iteration 80 / 1000: loss 15.066976
# SGD: iteration 90 / 1000: loss 16.026299
# SGD: iteration 100 / 1000: loss 15.898211
# SGD: iteration 110 / 1000: loss 15.422348
# SGD: iteration 120 / 1000: loss 15.449923
# SGD: iteration 130 / 1000: loss 15.740536
# SGD: iteration 140 / 1000: loss 15.160902
# SGD: iteration 150 / 1000: loss 15.016714
# SGD: iteration 160 / 1000: loss 16.203604
# SGD: iteration 170 / 1000: loss 16.097729
# SGD: iteration 180 / 1000: loss 15.441509
# SGD: iteration 190 / 1000: loss 15.729379
# SGD: iteration 200 / 1000: loss 15.186109
# SGD: iteration 210 / 1000: loss 15.919527
# SGD: iteration 220 / 1000: loss 15.208700
# SGD: iteration 230 / 1000: loss 14.891079
# SGD: iteration 240 / 1000: loss 14.991944
# SGD: iteration 250 / 1000: loss 16.399996
# SGD: iteration 260 / 1000: loss 15.179881
# SGD: iteration 270 / 1000: loss 15.322956
# SGD: iteration 280 / 1000: loss 14.860709
# SGD: iteration 290 / 1000: loss 15.153683
# SGD: iteration 300 / 1000: loss 15.626307
# SGD: iteration 310 / 1000: loss 14.773292
# SGD: iteration 320 / 1000: loss 15.669370
# SGD: iteration 330 / 1000: loss 15.569281
# SGD: iteration 340 / 1000: loss 15.709007
# SGD: iteration 350 / 1000: loss 15.289770
# SGD: iteration 360 / 1000: loss 15.342016
# SGD: iteration 370 / 1000: loss 14.687573
# SGD: iteration 380 / 1000: loss 16.182882
# SGD: iteration 390 / 1000: loss 16.104843
# SGD: iteration 400 / 1000: loss 16.520794
# SGD: iteration 410 / 1000: loss 14.797999
# SGD: iteration 420 / 1000: loss 15.224612
# SGD: iteration 430 / 1000: loss 14.362872
# SGD: iteration 440 / 1000: loss 14.581272
# SGD: iteration 450 / 1000: loss 15.036208
# SGD: iteration 460 / 1000: loss 15.561125
# SGD: iteration 470 / 1000: loss 15.477096
# SGD: iteration 480 / 1000: loss 15.309279
# SGD: iteration 490 / 1000: loss 16.007728
# SGD: iteration 500 / 1000: loss 14.297941
# SGD: iteration 510 / 1000: loss 14.612737
# SGD: iteration 520 / 1000: loss 15.633896
# SGD: iteration 530 / 1000: loss 15.397752
# SGD: iteration 540 / 1000: loss 14.987193
# SGD: iteration 550 / 1000: loss 15.756577
# SGD: iteration 560 / 1000: loss 14.834511
# SGD: iteration 570 / 1000: loss 15.813290
# SGD: iteration 580 / 1000: loss 15.315818
# SGD: iteration 590 / 1000: loss 15.768421
# SGD: iteration 600 / 1000: loss 15.158708
# SGD: iteration 610 / 1000: loss 15.316566
# SGD: iteration 620 / 1000: loss 15.696736
# SGD: iteration 630 / 1000: loss 15.528034
# SGD: iteration 640 / 1000: loss 15.833530
# SGD: iteration 650 / 1000: loss 14.484768
# SGD: iteration 660 / 1000: loss 15.878844
# SGD: iteration 670 / 1000: loss 16.121574
# SGD: iteration 680 / 1000: loss 15.204941
# SGD: iteration 690 / 1000: loss 15.361953
# SGD: iteration 700 / 1000: loss 15.403703
# SGD: iteration 710 / 1000: loss 15.229756
# SGD: iteration 720 / 1000: loss 14.952026
# SGD: iteration 730 / 1000: loss 16.742300
# SGD: iteration 740 / 1000: loss 14.807338
# SGD: iteration 750 / 1000: loss 14.500786
# SGD: iteration 760 / 1000: loss 15.397027
# SGD: iteration 770 / 1000: loss 15.564570
# SGD: iteration 780 / 1000: loss 16.429183
# SGD: iteration 790 / 1000: loss 14.965952
# SGD: iteration 800 / 1000: loss 16.156267
# SGD: iteration 810 / 1000: loss 16.133329
# SGD: iteration 820 / 1000: loss 16.235481
# SGD: iteration 830 / 1000: loss 14.916880
# SGD: iteration 840 / 1000: loss 15.003239
# SGD: iteration 850 / 1000: loss 15.618549
# SGD: iteration 860 / 1000: loss 15.983027
# SGD: iteration 870 / 1000: loss 15.331484
# SGD: iteration 880 / 1000: loss 15.490389
# SGD: iteration 890 / 1000: loss 16.651102
# SGD: iteration 900 / 1000: loss 15.292762
# SGD: iteration 910 / 1000: loss 15.350174
# SGD: iteration 920 / 1000: loss 15.125283
# SGD: iteration 930 / 1000: loss 15.800591
# SGD: iteration 940 / 1000: loss 15.328404
# SGD: iteration 950 / 1000: loss 15.538136
# SGD: iteration 960 / 1000: loss 16.247971
# SGD: iteration 970 / 1000: loss 16.083653
# SGD: iteration 980 / 1000: loss 16.225889
# SGD: iteration 990 / 1000: loss 15.157382
# 39.865153074264526 sec elapsed

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.29 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.show()

# %%
#from cs231n.vis_utils import visualize_grid
#from cs231n.vis_utils import visualize_grid_2D

# SHOW SOME WEIGHTS
W0 = net.weights[0]['W']
W0 = W0.T
num_of_samples=100
for i in range(0,10):
    for j in range(0,10):
        plt.subplot(10, 10, i*10+j+1)
        rand_index = np.random.random_integers(0,W0.shape[0]-1,1)
        plt.imshow(W0[rand_index].reshape(28,28))
        plt.axis('off')
plt.show()
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: DeprecationWarning: This function is deprecated. Please call randint(0, 299 + 1) instead
#   # This is added back by InteractiveShellApp.init_path()

# %%
# SHOW SOME RECONSTRUCTIONS
plt_index=1
for i in range(0,10):
    rand_index = np.random.random_integers(0,X_train.shape[0]-1,1)
    x = X_train[rand_index]
    x_noisy = GaussianNoise(rate=0.5,sd=0.5)(x)
    x_recon = net.predict(x_noisy)
    #x_loss,_ = net.loss(x_noisy, x, reg=0.0, activation_function='sigmoid')
    
    plt.subplot(10,3,plt_index)
    plt.imshow(x.reshape(28,28))
    plt.axis('off')
    if i == 0: plt.title('input')
    plt_index+=1
    plt.subplot(10,3,plt_index)
    plt.imshow(x_noisy.reshape(28,28))
    plt.axis('off')
    if i == 0: plt.title('corrupted input')
    plt_index+=1
    plt.subplot(10,3,plt_index)
    plt.imshow(x_recon.reshape(28,28))
    plt.axis('off')
    if i == 0: plt.title('reconstruction')
    plt_index+=1
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: DeprecationWarning: This function is deprecated. Please call randint(0, 49999 + 1) instead
#   after removing the cwd from sys.path.

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Look at the visualizations above and try to come up with strategies for improving your training. With some effort, I came up with the following weights (which are also not perfect) and reconstructions (which are quite good):
#
# <img src="dae_learned_representation.png">
#
# <img src="dae_learned_representation_demo.png">

# %%
import time

input_size = 28 * 28
hidden_size = 300 # Try also sizes bigger than 28*28

reg = 0.0001 # 3e-3

net = DenoisingAutoencoder((input_size, hidden_size, input_size))
net.init_weights(13)

# Train with SGD
tic = time.time()
stats = net.train_with_SGD(X_train, noise=GaussianNoise(rate=0.5,sd=0.5),
            learning_rate=0.006, learning_rate_decay=0.99, 
            reg=reg, num_iters=1000, batchsize=128, momentum='classic', mu=0.9, verbose=True, 
            activation_function='sigmoid')
toc = time.time()
print(toc-tic, 'sec elapsed')
#good - reg=0.0001, lr = 0.006, lrdecay=0.99, batch size=128
#200 iter lr - 0.009, decay =1
# Out:
# SGD: iteration 0 / 1000: loss 93.480786
# SGD: iteration 10 / 1000: loss 72.187122
# SGD: iteration 20 / 1000: loss 24.361787
# SGD: iteration 30 / 1000: loss 18.987237
# SGD: iteration 40 / 1000: loss 16.307340
# SGD: iteration 50 / 1000: loss 15.825958
# SGD: iteration 60 / 1000: loss 14.840316
# SGD: iteration 70 / 1000: loss 14.638421
# SGD: iteration 80 / 1000: loss 12.992562
# SGD: iteration 90 / 1000: loss 13.736103
# SGD: iteration 100 / 1000: loss 14.035860
# SGD: iteration 110 / 1000: loss 13.525897
# SGD: iteration 120 / 1000: loss 13.636915
# SGD: iteration 130 / 1000: loss 14.215986
# SGD: iteration 140 / 1000: loss 13.579826
# SGD: iteration 150 / 1000: loss 13.611751
# SGD: iteration 160 / 1000: loss 14.942033
# SGD: iteration 170 / 1000: loss 14.638073
# SGD: iteration 180 / 1000: loss 14.024410
# SGD: iteration 190 / 1000: loss 14.287650
# SGD: iteration 200 / 1000: loss 13.763610
# SGD: iteration 210 / 1000: loss 14.468489
# SGD: iteration 220 / 1000: loss 13.950409
# SGD: iteration 230 / 1000: loss 13.594247
# SGD: iteration 240 / 1000: loss 13.743169
# SGD: iteration 250 / 1000: loss 15.231985
# SGD: iteration 260 / 1000: loss 14.019418
# SGD: iteration 270 / 1000: loss 14.114912
# SGD: iteration 280 / 1000: loss 13.702847
# SGD: iteration 290 / 1000: loss 13.769408
# SGD: iteration 300 / 1000: loss 14.028077
# SGD: iteration 310 / 1000: loss 13.513813
# SGD: iteration 320 / 1000: loss 14.177747
# SGD: iteration 330 / 1000: loss 14.262677
# SGD: iteration 340 / 1000: loss 14.157469
# SGD: iteration 350 / 1000: loss 14.300353
# SGD: iteration 360 / 1000: loss 13.865320
# SGD: iteration 370 / 1000: loss 13.508179
# SGD: iteration 380 / 1000: loss 14.573237
# SGD: iteration 390 / 1000: loss 14.755072
# SGD: iteration 400 / 1000: loss 15.317149
# SGD: iteration 410 / 1000: loss 13.446698
# SGD: iteration 420 / 1000: loss 13.849267
# SGD: iteration 430 / 1000: loss 13.296798
# SGD: iteration 440 / 1000: loss 13.179208
# SGD: iteration 450 / 1000: loss 13.544908
# SGD: iteration 460 / 1000: loss 13.735094
# SGD: iteration 470 / 1000: loss 13.955387
# SGD: iteration 480 / 1000: loss 14.157914
# SGD: iteration 490 / 1000: loss 14.642839
# SGD: iteration 500 / 1000: loss 12.997295
# SGD: iteration 510 / 1000: loss 13.242236
# SGD: iteration 520 / 1000: loss 14.408139
# SGD: iteration 530 / 1000: loss 13.805990
# SGD: iteration 540 / 1000: loss 13.471827
# SGD: iteration 550 / 1000: loss 14.438853
# SGD: iteration 560 / 1000: loss 13.365255
# SGD: iteration 570 / 1000: loss 14.385735
# SGD: iteration 580 / 1000: loss 13.759537
# SGD: iteration 590 / 1000: loss 14.632904
# SGD: iteration 600 / 1000: loss 13.825130
# SGD: iteration 610 / 1000: loss 13.980083
# SGD: iteration 620 / 1000: loss 14.413825
# SGD: iteration 630 / 1000: loss 14.020981
# SGD: iteration 640 / 1000: loss 14.664819
# SGD: iteration 650 / 1000: loss 12.956758
# SGD: iteration 660 / 1000: loss 14.514662
# SGD: iteration 670 / 1000: loss 14.599025
# SGD: iteration 680 / 1000: loss 14.058337
# SGD: iteration 690 / 1000: loss 14.017482
# SGD: iteration 700 / 1000: loss 14.007902
# SGD: iteration 710 / 1000: loss 13.628592
# SGD: iteration 720 / 1000: loss 13.733161
# SGD: iteration 730 / 1000: loss 15.251570
# SGD: iteration 740 / 1000: loss 13.340572
# SGD: iteration 750 / 1000: loss 13.583426
# SGD: iteration 760 / 1000: loss 14.066571
# SGD: iteration 770 / 1000: loss 14.358468
# SGD: iteration 780 / 1000: loss 15.148199
# SGD: iteration 790 / 1000: loss 13.454518
# SGD: iteration 800 / 1000: loss 14.522341
# SGD: iteration 810 / 1000: loss 14.835708
# SGD: iteration 820 / 1000: loss 14.851897
# SGD: iteration 830 / 1000: loss 13.470225
# SGD: iteration 840 / 1000: loss 13.586302
# SGD: iteration 850 / 1000: loss 14.196784
# SGD: iteration 860 / 1000: loss 14.716199
# SGD: iteration 870 / 1000: loss 13.952923
# SGD: iteration 880 / 1000: loss 14.165758
# SGD: iteration 890 / 1000: loss 15.323728
# SGD: iteration 900 / 1000: loss 13.996920
# SGD: iteration 910 / 1000: loss 13.887735
# SGD: iteration 920 / 1000: loss 13.969122
# SGD: iteration 930 / 1000: loss 14.756620
# SGD: iteration 940 / 1000: loss 13.728082
# SGD: iteration 950 / 1000: loss 14.350718
# SGD: iteration 960 / 1000: loss 15.062164
# SGD: iteration 970 / 1000: loss 14.939877
# SGD: iteration 980 / 1000: loss 15.137770
# SGD: iteration 990 / 1000: loss 13.718605
# 31.982401132583618 sec elapsed

# %%
#from cs231n.vis_utils import visualize_grid
#from cs231n.vis_utils import visualize_grid_2D

# SHOW SOME WEIGHTS
W0 = net.weights[0]['W']
W0 = W0.T
num_of_samples=100
for i in range(0,10):
    for j in range(0,10):
        plt.subplot(10, 10, i*10+j+1)
        rand_index = np.random.random_integers(0,W0.shape[0]-1,1)
        plt.imshow(W0[rand_index].reshape(28,28))
        plt.axis('off')
plt.show()
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: DeprecationWarning: This function is deprecated. Please call randint(0, 299 + 1) instead
#   # This is added back by InteractiveShellApp.init_path()

# %%
# SHOW SOME RECONSTRUCTIONS
plt_index=1
for i in range(0,10):
    rand_index = np.random.random_integers(0,X_train.shape[0]-1,1)
    x = X_train[rand_index]
    x_noisy = GaussianNoise(rate=0.5,sd=0.5)(x)
    x_recon = net.predict(x_noisy)
    #x_loss,_ = net.loss(x_noisy, x, reg=0.0, activation_function='sigmoid')
    
    plt.subplot(10,3,plt_index)
    plt.imshow(x.reshape(28,28))
    plt.axis('off')
    if i == 0: plt.title('input')
    plt_index+=1
    plt.subplot(10,3,plt_index)
    plt.imshow(x_noisy.reshape(28,28))
    plt.axis('off')
    if i == 0: plt.title('corrupted input')
    plt_index+=1
    plt.subplot(10,3,plt_index)
    plt.imshow(x_recon.reshape(28,28))
    plt.axis('off')
    if i == 0: plt.title('reconstruction')
    plt_index+=1
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: DeprecationWarning: This function is deprecated. Please call randint(0, 49999 + 1) instead
#   after removing the cwd from sys.path.
